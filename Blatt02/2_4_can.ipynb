# %% [markdown]
# # Exercise 4)
# ## (a)
#
# <img src="probVelo.jpg">
#
# <img src="NormConstant.jpg" width="700" height="1000">
#
# ## (b)

# %%
import numpy as np
import scipy.constants as const
import scipy as sc
import matplotlib.pyplot as plt

# %% [markdown]
# ### $f(v)$ as a function of $v_m$

# %%
def ff(v, m, T):
    return (m/(2*np.pi*const.Boltzmann*T))**(3/2) * np.exp(-(m*v**2)/(2*const.Boltzmann*T))*4*np.pi*v**2


def f(v,v_m):
    return (1/(np.pi*v_m**2))**(3/2) * np.exp(-(v/v_m)**2)*4*np.pi*v**2

# %%
v = np.linspace(0,10,1000)


plt.plot(v, f(v, 1),"purple")
plt.tight_layout(pad=0, h_pad=1.08, w_pad=1.08)
plt.xlim(0,4)
plt.xlabel("velocity $v/v_m$")
plt.ylabel("velocity distribution")

plt.show()

# %% [markdown]
# ### calculating the means

# %%
v_m = np.linspace(0.1,10.1,100)
mean = np.zeros(len(v_m))



plt.plot(v_m, f(v_m, 1),"purple")
plt.tight_layout(pad=0, h_pad=1.08, w_pad=1.08)
plt.xlim(0.1,6.1)
plt.xlabel("$v_m$")
plt.ylabel("mean")

plt.show()

# %% [markdown]
# ### c)

# %%
def vm(m,T):
    return np.sqrt(2*const.Boltzmann*T/m)
T= np.linspace(0,1000,1000)
m = const.physical_constants["molar mass constant"]
m = m[0]*m[2]

plt.plot(T, f(vm(0.5, T), 1),1,"purple")
plt.tight_layout(pad=0, h_pad=1.08, w_pad=1.08)
#plt.xlim(0.1,6.1)
plt.xlabel("$v_m$")
plt.ylabel("mean")

plt.show()

# %%
m = const.physical_constants["molar mass constant"]
m = m[0]*m[2]
#m[0], m[2], m[0]*m[2]

# %%
print("The mean is", np.mean(f(v,1)), "in terms of v_m")
# Out:
# The mean is 0.09990000000000002 in terms of v_m
